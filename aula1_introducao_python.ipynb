# %% [markdown]
# <a href="https://colab.research.google.com/github/laracabral-byte/aula1_introducao_python/blob/main/aula1_introducao_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello, word! meu primeiro código no calab.")
# Out:
# hello, word! meu primeiro código no calab.

# %% [markdown]
# # Minha Primeira Aula de Python e IA
# Neste notebook, estou aprendendo a configurar o ambiente e gerenciar chaves de segurança.

# %%
from google.colab import userdata

# Busca o segredo guardado no painel da chave sem expor o texto na tela
api_key = userdata.get('GOOGLE_API_KEY')
print("Chave carregada com segurança!")
